# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime

#plt.figure()
df_weather_sales = pd.read_csv('../data/processed/joined_weather_sales_data.csv')
df_weather_sales.plot(x='datetime',y=['quantity','net price'])
# Out:
# <AxesSubplot:xlabel='datetime'>
