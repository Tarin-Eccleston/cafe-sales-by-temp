# %%
import pandas as pd

df = pd.read_csv('input.csv')

# Drop unimportant columns
df.drop('INV. No', inplace=True, axis=1)
df.drop('cash tray code', inplace=True, axis=1)
df.drop('balance before reduction', inplace=True, axis=1)
df.drop('all discounts', inplace=True, axis=1)
df.drop('Total discount %', inplace=True, axis=1)
df.drop('net price', inplace=True, axis=1)
df.drop('Item tax type', inplace=True, axis=1)
df.drop('table', inplace=True, axis=1)
df.drop('customer name', inplace=True, axis=1)
df.drop('telephone number', inplace=True, axis=1)
df.drop('note', inplace=True, axis=1)
df.drop('group', inplace=True, axis=1)
df.drop('branch', inplace=True, axis=1)

# Translate payment type into english



print(df.to_string())
# Out:
#      payment date payment time Receipt number / ID                                                            menu name order type  quantity unit price payment type     Category
# 0      01/10/2022        07:47               UTF9R                             P ลาเตั/Latteปกติ x 3กลับบ้าน x 150% x 1  Take Away         1         65         Cash       Frappe
# 1      01/10/2022        07:47               UTF9R                                      ลาเต้/Latteปกติ x 1กลับบ้าน x 1  Take Away         1         45         Cash          Hot
# 2      01/10/2022        08:10               Q3NFU                                ชาเขียว/Green Milk Teaปกติ x 175% x 1  Take Away         1         55         Cash         Iced
# 3      01/10/2022        08:26               FABB7                                        H โกโก้/Hot Cocoaกลับบ้าน x 1    Dine-In         2         45    คนละครึ่ง          Hot
# ...
